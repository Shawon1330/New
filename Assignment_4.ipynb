# %% [markdown]
# <a href="https://colab.research.google.com/github/Shawon1330/New/blob/main/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary library
import numpy as np

# Create a NumPy array with 20 random integers between 1 and 100
array = np.random.randint(1, 101, 20)

# Display the NumPy array
print("Array:", array)

# 1. Find the sum of all elements
# The np.sum() function computes the sum of all elements in the array.
total_sum = np.sum(array)
print("The Sum of all elements:", sum)

# 2. Find the maximum and minimum values in the array
# np.max() returns the maximum value and np.min() returns the minimum value in the array.
max_value = np.max(array)
min_value = np.min(array)

print("Max value:", max_value)
print("Min value:", min_value)

# 3. Perform element-wise multiplication with another array of size 20
# Create another random array of the same size (20 elements)
array2 = np.random.randint(1, 101, 20)

# Display second array
print("Second Array:", array2)

# Perform element-wise multiplication
# This multiplies each element of arr by the corresponding element of arr2.
result = array * array2

print("The Multiplication Result:", result)
# Out:
# Array: [71 68 10 89 92 20 24 46 42 78 71 13 37 44 29 18 38 73 85 61]
# The Sum of all elements: <built-in function sum>
# Max value: 92
# Min value: 10
# Second Array: [50 26 75 42 85 71 68  5 24 15 37 82 20 40 35 26 62 79 41 72]
# The Multiplication Result: [3550 1768  750 3738 7820 1420 1632  230 1008 1170 2627 1066  740 1760
#  1015  468 2356 5767 3485 4392]

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# 1. Create a DataFrame with 5 rows and 3 columns of random numbers
# The DataFrame is generated from a 5x3 matrix of random integers between 1 and 100.
data = np.random.randint(1, 101, (5, 3))
df = pd.DataFrame(data, columns=["A", "B", "C"])

# Display the DataFrame
print("DataFrame:")
print(df)

# 2. Compute the sum of each column
# The .sum() function computes the sum for each column in the DataFrame.
column_sum = df.sum()
print("\nSum of each column:")
print(column_sum)

# 3. Compute the mean of each column
# The .mean() function computes the mean (average) of each column in the DataFrame.
column_mean = df.mean()
print("\nMean of each column:")
print(column_mean)
# Out:
# DataFrame:
#     A   B   C
# 0  66  68  64
# 1  47  82  64
# 2  21  97  36
# 3  12  96  63
# 4  49  83  66
#
# Sum of each column:
# A    195
# B    426
# C    293
# dtype: int64
#
# Mean of each column:
# A    39.0
# B    85.2
# C    58.6
# dtype: float64
