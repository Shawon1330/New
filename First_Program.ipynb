# %% [markdown]
# <a href="https://colab.research.google.com/github/Shawon1330/New/blob/main/First_Program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Assalamualaikum')
# Out:
# Assalamualaikum

# %%
print('Pleased to be with Skill morph')
# Out:
# Pleased to be with Skill morph

# %%
print("I'm Shawon islam")
# Out:
# I'm Shawon islam
